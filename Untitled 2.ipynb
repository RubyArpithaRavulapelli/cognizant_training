# %%
import matplotlib.pyplot as plt
grade=["A","B","C"]
marks=[100,200,300]
plt.plot(grade,marks)
plt.show()

# %%
import matplotlib.pyplot as plt
product=["moblie","laptop","tablet"]
price=[1000,3000,5000]
plt.plot(product,price)
plt.show()

# %%
months=["jan","feb","mar"]
sales=[100,200,300]
profit=[20,40,70]
plt.plot(months,sales,label="sales",alpha=0.6)
plt.plot(months,profit,label="profit",alpha=0.6)
plt.legend()
plt.show()
