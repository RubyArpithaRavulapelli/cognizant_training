# %%
import numpy as np
salary=([10000,20000,65000,40000,30000,75000])
print(np.mean(salary))
# Out:
# 40000.0

# %%
import numpy as np
salary=([10000,20000,65000,40000,30000,75000])
print(np.median(salary))
# Out:
# 35000.0

# %%
from scipy import stats
data=[10,20,30,40,30]
print(stats.mode(data))
# Out:
# ModeResult(mode=np.int64(30), count=np.int64(2))

# %%
import numpy as np
salary=([10000,20000,65000,40000,30000,75000])
print(np.max(salary))
# Out:
# 75000

# %%
import numpy as np
salary=([10000,20000,65000,40000,30000,75000])
print(np.max(salary)- np.min(salary))
# Out:
# 65000

# %%
salary=([10000,20000,65000,40000,30000,75000])
print(np.var(salary))
# Out:
# 541666666.6666666

# %%
salary=([10000,20000,65000,40000,30000,75000])
print(np.std(salary))
# Out:
# 23273.733406281568

# %%
from scipy import stats
mark=[10,20,30,40,30]
print(stats.mode(mark))
print(np.max(mark)- np.min(mark))
print(np.var(mark))
print(np.std(mark))
print(np.mean(mark))
print(np.median(mark))
# Out:
# ModeResult(mode=np.int64(30), count=np.int64(2))
# 30
# 104.0
# 10.198039027185569
# 26.0
# 30.0
