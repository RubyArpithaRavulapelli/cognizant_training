# %%
name="Ruby Arpitha"
age=20
print(name)
print(age)
# Out:
# Ruby Arpitha
# 20

# %%
marks=[50,60,76,80,46,47]
print(marks[3])
print(marks[5])
# Out:
# 80
# 47

# %%
marks=[50,3,76,84]
print(marks[3])
print(marks[5])
# Out:
# 84
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 marks=[50,3,76,84]
#       2 print(marks[3])
# ----> 3 print(marks[5])
#
# IndexError: list index out of range

# %%
marks=75
if marks>= 34:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
marks=[87,90,4,76,32,87,67]
for m in marks:
    print(marks)
# Out:
# [87, 90, 4, 76, 32, 87, 67]
# [87, 90, 4, 76, 32, 87, 67]
# [87, 90, 4, 76, 32, 87, 67]
# [87, 90, 4, 76, 32, 87, 67]
# [87, 90, 4, 76, 32, 87, 67]
# [87, 90, 4, 76, 32, 87, 67]
# [87, 90, 4, 76, 32, 87, 67]

# %%
marks=[56,95,54,38,45,83]
print(marks[4])
# Out:
# 45

# %%
marks=[50,54,34,23,74,95,79]
if all(marks <= 40 for marks in marks):
    print("pass")
else:
    print("fail")
# Out:
# fail
