# %%
import pandas as pd
data={"Name":["Laxman","Sujatha","Amulya"],
      "Age":[45,40,22],
      "City":["Gdk","Knr","Rmg"]}
details=pd.DataFrame(data)
print(details)
# Out:
#       Name  Age City
# 0   Laxman   45  Gdk
# 1  Sujatha   40  Knr
# 2   Amulya   22  Rmg

# %%
import pandas as pd
data={"Name":["Laxman","Sujatha","Amulya"],
      "Age":[45,40,22],
      "City":["Gdk","Knr","Rmg"]}
details=pd.DataFrame(data)
print(details)
print(details.shape)
# Out:
#       Name  Age City
# 0   Laxman   45  Gdk
# 1  Sujatha   40  Knr
# 2   Amulya   22  Rmg
# (3, 3)

# %%
import pandas as pd
data={"Name":["Laxman","Sujatha","Amulya"],
      "Age":[45,40,22],
      "City":["Gdk","Knr","Rmg"]}
details=pd.DataFrame(data)
print(details.columns)
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
import pandas as pd
data={"Name":["Laxman","Sujatha","Amulya"],
      "Age":[45,40,22],
      "City":["Gdk","Knr","Rmg"]
     }
details=pd.DataFrame(data)
print(details.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
import pandas as pd
data={"Name":["Laxman","Sujatha","Amulya","sandy","siri","cherry"],
      "Age":[45,40,22,12,34,56],
      "City":["Gdk","Knr","Rmg","hyd","grpt","kmp"]
     }
details=pd.DataFrame(data)
print(details.head())
print(details.tail())
print(details.sample(2))
print(details.info())
print(details.describe())
print(details.Age)
print(details.loc[1])
print(details.loc[[0,1,2]])
print(details.iloc[1])
print(
# Out:
#       Name  Age  City
# 0   Laxman   45   Gdk
# 1  Sujatha   40   Knr
# 2   Amulya   22   Rmg
# 3    sandy   12   hyd
# 4     siri   34  grpt
#       Name  Age  City
# 1  Sujatha   40   Knr
# 2   Amulya   22   Rmg
# 3    sandy   12   hyd
# 4     siri   34  grpt
# 5   cherry   56   kmp
#       Name  Age  City
# 1  Sujatha   40   Knr
# 4     siri   34  grpt
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   City    6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes
# None
#              Age
# count   6.000000
# mean   34.833333
# std    15.904926
# min    12.000000
# 25%    25.000000
# 50%    37.000000
# 75%    43.750000
# max    56.000000
# 0    45
# 1    40
# 2    22
# 3    12
# 4    34
# 5    56
# Name: Age, dtype: int64
# Name    Sujatha
# ...

# %%
import pandas as pd
data={"Name":["Laxman","Sujatha","Amulya","sandy","siri","cherry"],
      "Age":[45,40,22,12,34,56],
      "City":["Gdk","Knr","Rmg","hyd","grpt","kmp"]
     }
details=pd.DataFrame(data)
print(details[details.Age>22])
print(details[details.Age<20])
# Out:
#       Name  Age  City
# 0   Laxman   45   Gdk
# 1  Sujatha   40   Knr
# 4     siri   34  grpt
# 5   cherry   56   kmp
#     Name  Age City
# 3  sandy   12  hyd

# %%
import pandas as pd
data={"Name":["Laxman","Sujatha","Amulya","sandy","siri","cherry"],
      "Age":[45,40,22,12,34,56],
      "City":["Gdk","Knr","Rmg","hyd","grpt","kmp"],
      "Grade":["A","B","C","D","E","F"]
     }
details=pd.DataFrame(data)
print(details[details.Age>20]),(details[details.Age<35])
print(details["Grade"])
# Out:
#       Name  Age  City Grade
# 0   Laxman   45   Gdk     A
# 1  Sujatha   40   Knr     B
# 2   Amulya   22   Rmg     C
# 4     siri   34  grpt     E
# 5   cherry   56   kmp     F
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# 5    F
# Name: Grade, dtype: object

# %%
import pandas as pd
data={"Name":["Laxman","Sujatha","Amulya","sandy","siri","cherry"],
      "Age":[45,40,22,12,34,56],
      "City":["Gdk","Knr","Rmg","hyd","grpt","kmp"],
      "Grade":["A","B","C","D","E","F"]
     }
details=pd.DataFrame(data)
details["Age"]=details["Age"]+2
print(details)
# Out:
#       Name  Age  City Grade
# 0   Laxman   47   Gdk     A
# 1  Sujatha   42   Knr     B
# 2   Amulya   24   Rmg     C
# 3    sandy   14   hyd     D
# 4     siri   36  grpt     E
# 5   cherry   58   kmp     F

# %%
import pandas as pd
data={"Name":["Laxman","Sujatha","Amulya","sandy","siri","cherry"],
      "Age":[45,40,22,12,34,56],
      "City":["Gdk","Knr","Rmg","hyd","grpt","kmp"],
      "Grade":["A","B","C","D","E","F"]
     }
details=pd.DataFrame(data)
print(details.isnull())
# Out:
#     Name    Age   City  Grade
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False
# 5  False  False  False  False

# %%
import pandas as pd
dataJoin=pd.DataFrame({
     "ID":[1,2,3],
    "Name":["cherry","sweety","sandhya"]})
print(dataJoin)
dataJoin2=pd.DataFrame({
    "ID":[1,2,3],
    "Marks":["10","20","30"]})
print(dataJoin2)
result=pd.merge(dataJoin,dataJoin2,on="ID",how="inner")
result=pd.merge(dataJoin,dataJoin2,on="ID",how="left")
# Out:
#    ID     Name
# 0   1   cherry
# 1   2   sweety
# 2   3  sandhya
#    ID Marks
# 0   1    10
# 1   2    20
# 2   3    30

# %%
import
leftjoin= np.merge(dataJoin,dataJoin2,on="ID",HOW="right")
print(leftjoin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 leftjoin= np.merge(dataJoin,dataJoin2,on="ID",HOW="right")
#       2 print(leftjoin)
#
# NameError: name 'np' is not defined
