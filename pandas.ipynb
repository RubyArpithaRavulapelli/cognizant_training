# %%
import pandas as pd
r=pd.Series([10,20,30])
print(r.sum())
# Out:
# 60

# %%
r=pd.Series([10,20,30])
print(r.sum())
print(r.max())
print(r.min())
print(r.mean())
# Out:
# 60
# 30
# 10
# 20.0

# %%
r=pd.Series([10,20,30])
print(r[r>=25])
# Out:
# 2    30
# dtype: int64

# %%
a=pd.Series([10,20,38,50,67,30])
print([a<42])
# Out:
# [0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool]

# %%
import numpy as np
a=pd.Series([10,20,38,np.nan,30])
print(a)
# Out:
# 0    10.0
# 1    20.0
# 2    38.0
# 3     NaN
# 4    30.0
# dtype: float64

# %%
import numpy as np
a=pd.Series([10,20,38,np.nan,30])
print(a)
print(a.isnull())
# Out:
# 0    10.0
# 1    20.0
# 2    38.0
# 3     NaN
# 4    30.0
# dtype: float64
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
import numpy as np
a=pd.Series([10,20,38,np.nan,30])
print(a)
print(a.isnull().sum())
print(a.fillna(0))
# Out:
# 0    10.0
# 1    20.0
# 2    38.0
# 3     NaN
# 4    30.0
# dtype: float64
# 1
# 0    10.0
# 1    20.0
# 2    38.0
# 3     0.0
# 4    30.0
# dtype: float64

# %%
import numpy as np
a=pd.Series([10,np.adr,20,38,np.nan,30])
print(a)
print(a.isnull().sum())
print(a.

# %%
names=pd.Series(["Arpitha","Ruby","Laxman"])
print(names)
# Out:
# 0    Arpitha
# 1       Ruby
# 2     Laxman
# dtype: object

# %%
names=pd.Series(["Arpitha","Ruby","Laxman"])
print(names)
print(names.str.upper())
# Out:
# 0    Arpitha
# 1       Ruby
# 2     Laxman
# dtype: object
# 0    ARPITHA
# 1       RUBY
# 2     LAXMAN
# dtype: object

# %%
names=pd.Series(["Arpitha","Ruby","Laxman"])
print(names)
print(names.str.lower())
# Out:
# 0    Arpitha
# 1       Ruby
# 2     Laxman
# dtype: object
# 0    arpitha
# 1       ruby
# 2     laxman
# dtype: object

# %%
r=pd.Series([2,21,43,76,9,53,80,95,99,63])
print(r.sort_values())
# Out:
# 0     2
# 4     9
# 1    21
# 2    43
# 5    53
# 9    63
# 3    76
# 6    80
# 7    95
# 8    99
# dtype: int64

# %%
r=pd.Series([2,21,43,76,9,53,80,95,99,63])
print(r.sort_values())
print(r.sort_values(ascending=False))
# Out:
# 0     2
# 4     9
# 1    21
# 2    43
# 5    53
# 9    63
# 3    76
# 6    80
# 7    95
# 8    99
# dtype: int64
# 8    99
# 7    95
# 6    80
# 3    76
# 9    63
# 5    53
# 2    43
# 1    21
# 4     9
# 0     2
# dtype: int64

# %%
r=pd.Series([2,21,43,76,9,53,80,95,99,63])
print(r.sort_values())
print(r.sort_values(ascending=False))
print(r.unique())
# Out:
# 0     2
# 4     9
# 1    21
# 2    43
# 5    53
# 9    63
# 3    76
# 6    80
# 7    95
# 8    99
# dtype: int64
# 8    99
# 7    95
# 6    80
# 3    76
# 9    63
# 5    53
# 2    43
# 1    21
# 4     9
# 0     2
# dtype: int64
# [ 2 21 43 76  9 53 80 95 99 63]

# %%
r=pd.Series([2,21,43,76,9,53,80,95,99,63])
print(r.value_counts())
# Out:
# 2     1
# 21    1
# 43    1
# 76    1
# 9     1
# 53    1
# 80    1
# 95    1
# 99    1
# 63    1
# Name: count, dtype: int64

# %%
r=pd.Series([2,21,43,76,99,63])
print(r.tolist())
# Out:
# [2, 21, 43, 76, 99, 63]

# %%
import numpy as np
import pandas as pd
a=pd.Series([10,np.nan,20,38,np.nan,30])
print(a)
print(a.dropna())
# Out:
# 0    10.0
# 1     NaN
# 2    20.0
# 3    38.0
# 4     NaN
# 5    30.0
# dtype: float64
# 0    10.0
# 2    20.0
# 3    38.0
# 5    30.0
# dtype: float64

# %%
import numpy as np
import pandas as pd
a=pd.Series([10,np.nan,20,38,np.nan,30])
print(a)
# Out:
# 0    10.0
# 1     NaN
# 2    20.0
# 3    38.0
# 4     NaN
# 5    30.0
# dtype: float64
